# %% [markdown]
# ### Importing Necessary Libraries:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 1 :Loading the Dataset 1:

# %%
dataset1="D:/Nexthike IT Solutions/Project-2 Data Wrangling/dataset_1.csv"
df1 = pd.read_csv(dataset1)
df1
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1  01-01-2011       1   0     1   0    False        6           1
# 1          2  01-01-2011       1   0     1   1    False        6           1
# 2          3  01-01-2011       1   0     1   2    False        6           1
# 3          4  01-01-2011       1   0     1   3    False        6           1
# 4          5  01-01-2011       1   0     1   4    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 605      606  28-01-2011       1   0     1  11    False        5           3
# 606      607  28-01-2011       1   0     1  12    False        5           3
# 607      608  28-01-2011       1   0     1  13    False        5           3
# 608      609  28-01-2011       1   0     1  14    False        5           3
# 609      610  28-01-2011       1   0     1  15    False        5           2
#
#      temp
# 0    0.24
# 1    0.22
# ...

# %%
# Convert 'dteday' column to datetime format
df1['dteday']=pd.to_datetime(df1['dteday'],dayfirst=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(7)
# memory usage: 43.6 KB

# %%
# We want to read all columns & check their names to avoid errors during out work 
df1 = pd.DataFrame(df1)
column_list = list(df1.columns)
column_list
# Out:
# ['instant',
#  'dteday',
#  'season',
#  'yr',
#  'mnth',
#  'hr',
#  'holiday',
#  'weekday',
#  'weathersit',
#  'temp']

# %% [markdown]
# ### Inspecting the Data:

# %% [markdown]
# #### Check for Description,N/A values,Duplicate values, Identify Unique values,Missing values for dataset 1.

# %%
# Checking the description
df1.describe()
# Out:
#           instant                         dteday  season     yr   mnth  \
# count  610.000000                            610   610.0  610.0  610.0
# mean   305.500000  2011-01-13 19:47:24.590163968     1.0    0.0    1.0
# min      1.000000            2011-01-01 00:00:00     1.0    0.0    1.0
# 25%    153.250000            2011-01-07 00:00:00     1.0    0.0    1.0
# 50%    305.500000            2011-01-14 00:00:00     1.0    0.0    1.0
# 75%    457.750000            2011-01-21 00:00:00     1.0    0.0    1.0
# max    610.000000            2011-01-28 00:00:00     1.0    0.0    1.0
# std    176.236111                            NaN     0.0    0.0    0.0
#
#                hr     weekday  weathersit        temp
# count  610.000000  610.000000  610.000000  610.000000
# mean    11.795082    2.977049    1.477049    0.196885
# min      0.000000    0.000000    1.000000    0.020000
# 25%      6.000000    1.000000    1.000000    0.160000
# 50%     12.000000    3.000000    1.000000    0.200000
# ...

# %%
# Checking for any N/A values
df1.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %%
# Checking for any duplicates values
df1.duplicated().sum()
# Out:
# 0

# %%
# Identify unique values
unique_values={col:df1[col].nunique() for col in df1.columns}
print("Unique Values:", unique_values)
# Out:
# Unique Values: {'instant': 610, 'dteday': 28, 'season': 1, 'yr': 1, 'mnth': 1, 'hr': 24, 'holiday': 2, 'weekday': 7, 'weathersit': 4, 'temp': 23}

# %%
# Checking for any missing values
missing_value_df1 = df1.isnull().sum()
print("\n missing value in dataset 1:\n",missing_value_df1)
# Out:
#  missing value in dataset 1:
#  instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# dtype: int64

# %% [markdown]
# ## Data Visualization for dataset 1

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# Generate sample data
season = ['spring', 'summer', 'fall','winter']
weather = ['Few_clouds', 'Mist', 'Light_Rain', 'Heavy_Rain']

# Create the plot
plt.figure(figsize=(10, 6))
bars = plt.bar(season, weather, color=sns.color_palette("husl", 5))

# Customize the plot
plt.title('Bar Graph', fontsize=16)
plt.xlabel('Season', fontsize=12)
plt.ylabel('Weather', fontsize=12)

# Add value labels on top of each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height}',
             ha='center', va='bottom')

plt.show()

# %%
# Generate some sample data
x = np.linspace(0.2, 0.46, 100)
y = np.sin(x)

# Create a new figure
plt.figure(figsize=(10, 6))

# Plot the data
plt.plot(x, y)

# Add labels and title
plt.xlabel('Temp')
plt.ylabel('Season')
plt.title('Line Plot')

# Show the plot
plt.show()

# %%
# Windspeed percentage
sns.set_style('darkgrid')
plt.figure(figsize=(12,6))
plt.pie(df1['weathersit'].value_counts(),labels = df1['weathersit'].value_counts().index, autopct='%1.1f%%')
plt.title("weathersit")
# Out:
# Text(0.5, 1.0, 'weathersit')

# %% [markdown]
# ### Step 2: Loading the Dataset 2:

# %%
dataset2="D:/Nexthike IT Solutions/Project-2 Data Wrangling/dataset_2.csv"
df2 = pd.read_csv(dataset2)
df2
# Out:
#      Unnamed: 0  instant   atemp   hum  windspeed  casual  registered  cnt
# 0             0        1  0.2879  0.81     0.0000       3          13   16
# 1             1        2  0.2727  0.80     0.0000       8          32   40
# 2             2        3  0.2727  0.80     0.0000       5          27   32
# 3             3        4  0.2879  0.75     0.0000       3          10   13
# 4             4        5  0.2879  0.75     0.0000       0           1    1
# ..          ...      ...     ...   ...        ...     ...         ...  ...
# 605         605      606  0.2121  0.93     0.1045       0          30   30
# 606         606      607  0.2121  0.93     0.1045       1          28   29
# 607         607      608  0.2121  0.93     0.1045       0          31   31
# 608         608      609  0.2727  0.80     0.0000       2          36   38
# 609         609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 8 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  610 non-null    int64
#  1   instant     610 non-null    int64
#  2   atemp       599 non-null    float64
#  3   hum         610 non-null    float64
#  4   windspeed   610 non-null    float64
#  5   casual      610 non-null    int64
#  6   registered  610 non-null    int64
#  7   cnt         610 non-null    int64
# dtypes: float64(3), int64(5)
# memory usage: 38.3 KB

# %%
# Drop column 'Unnamed'
df2 = df2.loc[:, ~df2.columns.str.contains('^Unnamed')]
df2
# Out:
#      instant   atemp   hum  windspeed  casual  registered  cnt
# 0          1  0.2879  0.81     0.0000       3          13   16
# 1          2  0.2727  0.80     0.0000       8          32   40
# 2          3  0.2727  0.80     0.0000       5          27   32
# 3          4  0.2879  0.75     0.0000       3          10   13
# 4          5  0.2879  0.75     0.0000       0           1    1
# ..       ...     ...   ...        ...     ...         ...  ...
# 605      606  0.2121  0.93     0.1045       0          30   30
# 606      607  0.2121  0.93     0.1045       1          28   29
# 607      608  0.2121  0.93     0.1045       0          31   31
# 608      609  0.2727  0.80     0.0000       2          36   38
# 609      610  0.2576  0.86     0.0000       1          40   41
#
# [610 rows x 7 columns]

# %%
# We want to read all columns & check their names to avoid errors during out work 
df2 = pd.DataFrame(df2)
column_list = list(df2.columns)
column_list
# Out:
# ['instant', 'atemp', 'hum', 'windspeed', 'casual', 'registered', 'cnt']

# %% [markdown]
# ### Inspecting the Data:

# %% [markdown]
# #### Check for Description,N/A values,Duplicate values,Identify unique values,Missing values for dataset 2

# %%
# Checking the description
df2.describe()
# Out:
#           instant       atemp         hum   windspeed      casual  registered  \
# count  610.000000  599.000000  610.000000  610.000000  610.000000  610.000000
# mean   305.500000    0.199935    0.562475    0.204851    4.501639   51.068852
# std    176.236111    0.078836    0.175440    0.121806    6.319945   47.021204
# min      1.000000    0.000000    0.210000    0.000000    0.000000    0.000000
# 25%    153.250000    0.151500    0.432500    0.104500    0.000000   14.000000
# 50%    305.500000    0.197000    0.520000    0.194000    2.000000   43.000000
# 75%    457.750000    0.242400    0.690000    0.283600    6.000000   70.000000
# max    610.000000    0.454500    1.000000    0.582100   47.000000  247.000000
#
#               cnt
# count  610.000000
# mean    55.570492
# std     49.316802
# min      1.000000
# 25%     16.000000
# 50%     47.000000
# 75%     79.750000
# max    249.000000

# %%
# Checking for any N/A values
df2.isna().sum()
# Out:
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
# Checking for any duplicates values
df2.duplicated().sum()
# Out:
# 0

# %%
# Identify unique values
unique_values={col:df2[col].nunique() for col in df2.columns}
print("Unique Values:", unique_values)
# Out:
# Unique Values: {'instant': 610, 'atemp': 29, 'hum': 61, 'windspeed': 20, 'casual': 32, 'registered': 150, 'cnt': 165}

# %%
# Checking for any missing values
missing_value_df2 = df2.isnull().sum()
print("\n missing value in dataset 2:\n",missing_value_df2)
# Out:
#  missing value in dataset 2:
#  instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %% [markdown]
# ## Data Visualization for dataset 2

# %%
# Windspeed percentage
sns.set_style('darkgrid')
plt.figure(figsize=(18,9))
plt.pie(df2['windspeed'].value_counts(),labels = df2['windspeed'].value_counts().index, autopct='%1.1f%%')
plt.title("windspeed")
# Out:
# Text(0.5, 1.0, 'windspeed')

# %%
# Temperature percentage
colors=['grey', 'blue', 'red', 'yellow', 'lightcoral', 'lightskyblue', 'gold']
counts = df2["atemp"].value_counts()
counts.plot (kind='pie',fontsize=8, autopct= '%1.1f%%', colors=colors)
plt.xlabel('atemp', weight="bold", fontsize=8, labelpad=20)
plt.axis('equal')
plt.legend(labels=counts.index, loc="best")
plt.show()

# %% [markdown]
# ### Step 3 Concatination & Mergering of dataset 1 & dataset 2 as df12

# %%
# using a concat() method
df12 = pd.concat([df1, df2], axis=1, join='inner')
df12
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
# ...

# %%
# Merge the both dataset
instant = list(set(df1.columns) & set(df2.columns))
merged_df12 = pd.merge(df1, df2, on=instant, how='inner')

# %%
# Display the merged dataset
display(merged_df12)
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 605      606 2011-01-28       1   0     1  11    False        5           3
# 606      607 2011-01-28       1   0     1  12    False        5           3
# 607      608 2011-01-28       1   0     1  13    False        5           3
# 608      609 2011-01-28       1   0     1  14    False        5           3
# 609      610 2011-01-28       1   0     1  15    False        5           2
#
# ...

# %%
# Convert 'dteday' column to datetime format
df12['dteday']=pd.to_datetime(df12['dteday'],dayfirst=True)

# %%
df12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     610 non-null    int64
#  1   dteday      610 non-null    datetime64[ns]
#  2   season      610 non-null    int64
#  3   yr          610 non-null    int64
#  4   mnth        610 non-null    int64
#  5   hr          610 non-null    int64
#  6   holiday     610 non-null    bool
#  7   weekday     610 non-null    int64
#  8   weathersit  610 non-null    int64
#  9   temp        610 non-null    float64
#  10  instant     610 non-null    int64
#  11  atemp       599 non-null    float64
#  12  hum         610 non-null    float64
#  13  windspeed   610 non-null    float64
#  14  casual      610 non-null    int64
#  15  registered  610 non-null    int64
#  16  cnt         610 non-null    int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(11)
# memory usage: 77.0 KB

# %%
# We want to read all columns & check their names to avoid errors during out work 
df12 = pd.DataFrame(df12)
column_list = list(df12.columns)
column_list
# Out:
# ['instant',
#  'dteday',
#  'season',
#  'yr',
#  'mnth',
#  'hr',
#  'holiday',
#  'weekday',
#  'weathersit',
#  'temp',
#  'instant',
#  'atemp',
#  'hum',
#  'windspeed',
#  'casual',
#  'registered',
#  'cnt']

# %% [markdown]
# ### Inspecting the Data:

# %% [markdown]
# #### Check for Description,N/A values,Duplicate values,Identify unique values,Missing values for df12.

# %%
# Checking the description
df12.describe()
# Out:
#           instant                         dteday  season     yr   mnth  \
# count  610.000000                            610   610.0  610.0  610.0
# mean   305.500000  2011-01-13 19:47:24.590163968     1.0    0.0    1.0
# min      1.000000            2011-01-01 00:00:00     1.0    0.0    1.0
# 25%    153.250000            2011-01-07 00:00:00     1.0    0.0    1.0
# 50%    305.500000            2011-01-14 00:00:00     1.0    0.0    1.0
# 75%    457.750000            2011-01-21 00:00:00     1.0    0.0    1.0
# max    610.000000            2011-01-28 00:00:00     1.0    0.0    1.0
# std    176.236111                            NaN     0.0    0.0    0.0
#
#                hr     weekday  weathersit        temp     instant       atemp  \
# count  610.000000  610.000000  610.000000  610.000000  610.000000  599.000000
# mean    11.795082    2.977049    1.477049    0.196885  305.500000    0.199935
# min      0.000000    0.000000    1.000000    0.020000    1.000000    0.000000
# ...

# %%
# Checking for any N/A values
df12.isna().sum()
# Out:
# instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
# Checking for any duplicates values
df12.duplicated().sum()
# Out:
# 0

# %%
# Identify unique values
unique_values={col:df12[col].nunique() for col in df12.columns}
print("Unique Values:", unique_values)
# Out:
# Unique Values: {'instant': instant    610
# instant    610
# dtype: int64, 'dteday': 28, 'season': 1, 'yr': 1, 'mnth': 1, 'hr': 24, 'holiday': 2, 'weekday': 7, 'weathersit': 4, 'temp': 23, 'atemp': 29, 'hum': 61, 'windspeed': 20, 'casual': 32, 'registered': 150, 'cnt': 165}

# %%
# Checking for any missing values
missing_value_df12 = df12.isnull().sum()
print("\n missing value in dataset 12:\n",missing_value_df12)
# Out:
#  missing value in dataset 12:
#  instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %% [markdown]
# ## Data Visualization for df12

# %%
# Humidity in all seasons
Humidity_counts = df12['hum'].value_counts()
plt.figure(figsize=(16, 6))
Humidity_counts.plot(kind='bar', color= 'skyblue')
plt.title('Humidity in all seasons')
plt.xlabel('humidity')
plt.ylabel('season')
plt.xticks(rotation=90, ha='right') # Adjust rotation for better readability 
plt.show()

# %%
# Weathersit in all seasons
weathersit_counts = df12['weathersit'].value_counts()
plt.figure(figsize=(10, 6))
bars = weathersit_counts.plot(kind='bar', color=colors)

for bar, count in zip(bars.patches, weathersit_counts):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.05, str(count), fontsize=10)
plt.title('Weathersit in seasons')
plt.xlabel('season')
plt.ylabel('weathersit')
plt.xticks(rotation=0, ha='right')
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, '1'), Text(1, 0, '2'), Text(2, 0, '3'), Text(3, 0, '4')])

# %% [markdown]
# ### Step 4 :Loading the Dataset 3:

# %%
dataset3="D:/Nexthike IT Solutions/Project-2 Data Wrangling/dataset_3.csv"
df3 = pd.read_csv(dataset3)
df3
# Out:
#      instant      dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0        620  29-01-2011       1   0     1   1    False        6           1
# 1        621  29-01-2011       1   0     1   2    False        6           1
# 2        622  29-01-2011       1   0     1   3    False        6           1
# 3        623  29-01-2011       1   0     1   4    False        6           1
# 4        624  29-01-2011       1   0     1   6    False        6           1
# ..       ...         ...     ...  ..   ...  ..      ...      ...         ...
# 385      615  28-01-2011       1   0     1  20    False        5           2
# 386      616  28-01-2011       1   0     1  21    False        5           2
# 387      617  28-01-2011       1   0     1  22    False        5           1
# 388      618  28-01-2011       1   0     1  23    False        5           1
# 389      619  29-01-2011       1   0     1   0    False        6           1
#
# ...

# %%
# Convert 'dteday' column to datetime format
df3['dteday']=pd.to_datetime(df3['dteday'],dayfirst=True)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    datetime64[ns]
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  atemp       390 non-null    float64
#  11  hum         390 non-null    float64
#  12  windspeed   390 non-null    float64
#  13  casual      390 non-null    int64
#  14  registered  390 non-null    int64
#  15  cnt         390 non-null    int64
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(10)
# memory usage: 46.2 KB

# %%
# We want to read all columns & check their names to avoid errors during out work 
df3 = pd.DataFrame(df3)
column_list = list(df3.columns)
column_list
# Out:
# ['instant',
#  'dteday',
#  'season',
#  'yr',
#  'mnth',
#  'hr',
#  'holiday',
#  'weekday',
#  'weathersit',
#  'temp',
#  'atemp',
#  'hum',
#  'windspeed',
#  'casual',
#  'registered',
#  'cnt']

# %% [markdown]
# ### Inspecting the Data:

# %% [markdown]
# #### Check for Description,N/A values,Duplicate values, Identify Unique values,Missing values for dataset 3.

# %%
# Checking the description
df3.describe()
# Out:
#            instant                         dteday  season     yr        mnth  \
# count   390.000000                            390   390.0  390.0  390.000000
# mean    805.500000  2011-02-05 11:45:13.846153728     1.0    0.0    1.800000
# min     611.000000            2011-01-28 00:00:00     1.0    0.0    1.000000
# 25%     708.250000            2011-02-01 00:00:00     1.0    0.0    2.000000
# 50%     805.500000            2011-02-05 12:00:00     1.0    0.0    2.000000
# 75%     902.750000            2011-02-10 00:00:00     1.0    0.0    2.000000
# max    1000.000000            2011-02-14 00:00:00     1.0    0.0    2.000000
# std     112.727548                            NaN     0.0    0.0    0.400514
#
#                hr     weekday  weathersit        temp       atemp         hum  \
# count  390.000000  390.000000  390.000000  390.000000  390.000000  390.000000
# mean    11.687179    2.989744    1.484615    0.220000    0.230424    0.613769
# ...

# %%
# Checking for any N/A values
df3.isna().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
# Checking for any duplicates values
df3.duplicated().sum()
# Out:
# 0

# %%
# Identify unique values
unique_values={col:df3[col].nunique() for col in df3.columns}
print("Unique Values:", unique_values)
# Out:
# Unique Values: {'instant': 390, 'dteday': 18, 'season': 1, 'yr': 1, 'mnth': 2, 'hr': 24, 'holiday': 1, 'weekday': 7, 'weathersit': 3, 'temp': 19, 'atemp': 22, 'hum': 58, 'windspeed': 20, 'casual': 36, 'registered': 146, 'cnt': 144}

# %%
# Checking for any missing values
missing_value_df3 = df3.isnull().sum()
print("\n missing value in dataset 3:\n",missing_value_df3)
# Out:
#  missing value in dataset 3:
#  instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# ### Data Visualization for dataset 3

# %%
# Hours percentage
sns.set_style('darkgrid')
plt.figure(figsize=(18,9))
plt.pie(df3['hr'].value_counts(),labels = df3['hr'].value_counts().index, autopct='%1.1f%%')
plt.title("Hours")
# Out:
# Text(0.5, 1.0, 'Hours')

# %%
# Count of total rental in all season 
cnt_counts = df3['cnt'].value_counts()
plt.figure(figsize=(10, 6))
bars = weathersit_counts.plot(kind='bar', color=colors)

for bar, count in zip(bars.patches, weathersit_counts):
    plt.text(bar.get_x() + bar.get_width() / 2 - 0.1, bar.get_height() + 0.05, str(count), fontsize=10)
plt.title('Count of total rental')
plt.xlabel('season')
plt.ylabel('cnt')
plt.xticks(rotation=0, ha='right')
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, '1'), Text(1, 0, '2'), Text(2, 0, '3'), Text(3, 0, '4')])

# %% [markdown]
# ### Step 5 Concatination & Mergering of dataset 3 & df12 as Final data

# %%
# using a concat() method
final_data = pd.concat([df12, df3], axis=1, join='inner')
final_data
# Out:
#      instant     dteday  season  yr  mnth  hr  holiday  weekday  weathersit  \
# 0          1 2011-01-01       1   0     1   0    False        6           1
# 1          2 2011-01-01       1   0     1   1    False        6           1
# 2          3 2011-01-01       1   0     1   2    False        6           1
# 3          4 2011-01-01       1   0     1   3    False        6           1
# 4          5 2011-01-01       1   0     1   4    False        6           1
# ..       ...        ...     ...  ..   ...  ..      ...      ...         ...
# 385      386 2011-01-17       1   0     1  13     True        1           2
# 386      387 2011-01-17       1   0     1  14     True        1           2
# 387      388 2011-01-17       1   0     1  15     True        1           2
# 388      389 2011-01-17       1   0     1  16     True        1           2
# 389      390 2011-01-17       1   0     1  17     True        1           1
#
# ...

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     390 non-null    int64
#  1   dteday      390 non-null    datetime64[ns]
#  2   season      390 non-null    int64
#  3   yr          390 non-null    int64
#  4   mnth        390 non-null    int64
#  5   hr          390 non-null    int64
#  6   holiday     390 non-null    bool
#  7   weekday     390 non-null    int64
#  8   weathersit  390 non-null    int64
#  9   temp        390 non-null    float64
#  10  instant     390 non-null    int64
#  11  atemp       379 non-null    float64
#  12  hum         390 non-null    float64
#  13  windspeed   390 non-null    float64
#  14  casual      390 non-null    int64
#  15  registered  390 non-null    int64
#  16  cnt         390 non-null    int64
#  17  instant     390 non-null    int64
#  18  dteday      390 non-null    datetime64[ns]
# ...

# %%
# We want to read all columns & check their names to avoid errors during out work 
final_data = pd.DataFrame(final_data)
column_list = list(final_data.columns)
column_list
# Out:
# ['instant',
#  'dteday',
#  'season',
#  'yr',
#  'mnth',
#  'hr',
#  'holiday',
#  'weekday',
#  'weathersit',
#  'temp',
#  'instant',
#  'atemp',
#  'hum',
#  'windspeed',
#  'casual',
#  'registered',
#  'cnt',
#  'instant',
#  'dteday',
#  'season',
#  'yr',
#  'mnth',
#  'hr',
#  'holiday',
#  'weekday',
#  'weathersit',
#  'temp',
#  'atemp',
#  'hum',
#  'windspeed',
#  'casual',
#  'registered',
#  'cnt']

# %% [markdown]
# ### Inspecting the Data:

# %% [markdown]
# #### Check for Description,N/A values,Duplicate values,Identify unique values,Missing values for final data.

# %%
# Checking the description
final_data.describe()
# Out:
#           instant                         dteday  season     yr   mnth  \
# count  390.000000                            390   390.0  390.0  390.0
# mean   195.500000  2011-01-08 22:09:13.846153728     1.0    0.0    1.0
# min      1.000000            2011-01-01 00:00:00     1.0    0.0    1.0
# 25%     98.250000            2011-01-05 00:00:00     1.0    0.0    1.0
# 50%    195.500000            2011-01-09 00:00:00     1.0    0.0    1.0
# 75%    292.750000            2011-01-13 00:00:00     1.0    0.0    1.0
# max    390.000000            2011-01-17 00:00:00     1.0    0.0    1.0
# std    112.727548                            NaN     0.0    0.0    0.0
#
#                hr     weekday  weathersit        temp     instant  ...  \
# count  390.000000  390.000000  390.000000  390.000000  390.000000  ...
# mean    11.612821    2.920513    1.389744    0.206308  195.500000  ...
# min      0.000000    0.000000    1.000000    0.080000    1.000000  ...
# ...

# %%
# Checking for any N/A values
final_data.isna().sum()
# Out:
# instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# atemp          0
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %%
# Checking for any duplicates values
final_data.duplicated().sum()
# Out:
# 0

# %%
# Identify unique values
unique_values={col:final_data[col].nunique() for col in final_data.columns}
print("Unique Values:", unique_values)
# Out:
# Unique Values: {'instant': instant    390
# instant    390
# instant    390
# dtype: int64, 'dteday': dteday    17
# dteday    18
# dtype: int64, 'season': season    1
# season    1
# dtype: int64, 'yr': yr    1
# yr    1
# dtype: int64, 'mnth': mnth    1
# mnth    2
# dtype: int64, 'hr': hr    24
# hr    24
# dtype: int64, 'holiday': holiday    2
# holiday    1
# dtype: int64, 'weekday': weekday    7
# weekday    7
# dtype: int64, 'weathersit': weathersit    3
# weathersit    3
# dtype: int64, 'temp': temp    20
# temp    19
# dtype: int64, 'atemp': atemp    25
# atemp    22
# dtype: int64, 'hum': hum    50
# hum    58
# dtype: int64, 'windspeed': windspeed    20
# windspeed    20
# dtype: int64, 'casual': casual    31
# casual    36
# dtype: int64, 'registered': registered    124
# registered    146
# dtype: int64, 'cnt': cnt    139
# cnt    144
# dtype: int64}

# %%
# Checking for any missing values
missing_value_final_data = final_data.isnull().sum()
print("\n missing value in final_data:\n",missing_value_final_data)
# Out:
#  missing value in final_data:
#  instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# instant        0
# atemp         11
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# hr             0
# holiday        0
# weekday        0
# weathersit     0
# temp           0
# atemp          0
# hum            0
# windspeed      0
# casual         0
# registered     0
# cnt            0
# dtype: int64

# %% [markdown]
# ### Calculating Outliers,Skewness & Kurtosis

# %% [markdown]
# #### Importing Necessary Libraries:

# %%
# Importing scipy 
import scipy
from scipy.stats import skew
from scipy.stats import kurtosis
import seaborn as sns

# %%
# Outliers Detection using IqR (Only for numeric columns) 
numeric_cols=final_data.select_dtypes(include=['number']).columns
Q1=final_data[numeric_cols].quantile(0.25)
Q3=final_data[numeric_cols].quantile(0.75)
IQR=Q3-Q1

outliers = ((final_data[numeric_cols] < (Q1 - 1.5 * IQR)) | (final_data[numeric_cols] > (Q3 + 1.5 * IQR))).sum()
print("Outliers Count Per Column:\n", outliers)
# Out:
# Outliers Count Per Column:
#  instant        0
# instant        0
# instant        0
# season         0
# season         0
#               ..
# casual        37
# registered    19
# registered     9
# cnt           13
# cnt            8
# Length: 61, dtype: int64

# %%
# Calculate the skewness 
numeric_cols_excluding_datetime = final_data.select_dtypes(include=['number']).columns
df_skew = final_data[numeric_cols_excluding_datetime].skew()
df_skew.drop(labels=['season','yr'], errors='ignore', inplace=True)
print("Skewness: \n", df_skew)
# Out:
# Skewness:
#  instant       0.000000
# instant       0.000000
# instant       0.000000
# mnth          0.000000
# mnth         -1.505798
# hr           -0.034800
# hr           -0.050086
# weekday       0.081522
# weekday       0.014906
# weathersit    1.171832
# weathersit    1.037234
# temp          1.369801
# temp          0.479548
# instant       0.000000
# instant       0.000000
# instant       0.000000
# atemp         1.081665
# atemp         0.440540
# hum           0.860553
# hum           0.161484
# windspeed     0.266860
# windspeed     0.620359
# casual        2.624594
# casual        3.413724
# registered    1.366312
# registered    1.115912
# cnt           1.147964
# cnt           0.987140
# instant       0.000000
# instant       0.000000
# instant       0.000000
# mnth          0.000000
# mnth         -1.505798
# hr           -0.034800
# hr           -0.050086
# weekday       0.081522
# weekday       0.014906
# weathersit    1.171832
# weathersit    1.037234
# ...

# %%
# Correlation matrix (excluding categorical columns)
numeric_features=final_data.select_dtypes(include=['number']).columns
df_corr = final_data[numeric_features].corr()
print("Correlation Matrix:\n", df_corr)
# Out:
# Correlation Matrix:
#               instant   instant   instant  season  season  yr  yr  mnth  \
# instant     1.000000  1.000000  0.864733     NaN     NaN NaN NaN   NaN
# instant     1.000000  1.000000  0.864733     NaN     NaN NaN NaN   NaN
# instant     0.864733  0.864733  1.000000     NaN     NaN NaN NaN   NaN
# season           NaN       NaN       NaN     NaN     NaN NaN NaN   NaN
# season           NaN       NaN       NaN     NaN     NaN NaN NaN   NaN
# ...              ...       ...       ...     ...     ...  ..  ..   ...
# casual      0.194237  0.194237  0.219238     NaN     NaN NaN NaN   NaN
# registered  0.021941  0.021941 -0.006387     NaN     NaN NaN NaN   NaN
# registered  0.057559  0.057559  0.041795     NaN     NaN NaN NaN   NaN
# cnt         0.010367  0.010367 -0.025133     NaN     NaN NaN NaN   NaN
# cnt         0.086987  0.086987  0.076839     NaN     NaN NaN NaN   NaN
#
#                 mnth        hr  ...       hum       hum  windspeed  windspeed  \
# ...

# %%
#Compute correlation matrix
numeric_features = final_data.select_dtypes(include=['number']).columns
df_corr = final_data[numeric_features].corr()

#Drop columns that contain only NaN volues in the correlation matrix
df_corr_cleaned = df_corr.dropna(how='all', axis=1).dropna(how ='all', axis=0)
print("Cleaned Correlation Matrix:\n", df_corr_cleaned)
# Out:
# Cleaned Correlation Matrix:
#               instant   instant   instant      mnth        hr        hr  \
# instant     1.000000  1.000000  0.864733  0.532940  0.013838  0.046149
# instant     1.000000  1.000000  0.864733  0.532940  0.013838  0.046149
# instant     0.864733  0.864733  1.000000  0.692823 -0.002380 -0.018596
# mnth        0.532940  0.532940  0.692823  1.000000 -0.027374 -0.056458
# hr          0.013838  0.013838 -0.002380 -0.027374  1.000000  0.629711
# hr          0.046149  0.046149 -0.018596 -0.056458  0.629711  1.000000
# weekday    -0.021048 -0.021048  0.050089  0.156827  0.012510 -0.002505
# weekday     0.079035  0.079035  0.000053  0.093148  0.002000  0.050662
# weathersit -0.004558 -0.004558 -0.074003 -0.151725 -0.022939 -0.004770
# weathersit -0.238264 -0.238264 -0.220022  0.027074 -0.069473 -0.054857
# temp       -0.398058 -0.398058 -0.370810 -0.537188  0.187890  0.135193
# temp        0.178654  0.178654  0.164053  0.126446  0.292075  0.278821
# ...

# %% [markdown]
# ### Data Visualization for final data

# %%
plt.figure(figsize=(10, 5))
sns.histplot(final_data['cnt'], bins=30, kde=True, color='black')
plt.title("Histogram")
plt.xlabel("Total Rentals")
plt.ylabel("Temperature")
plt.show()

# %%
#Drop non-numeric columns before correlation analysis
numeric_df = final_data.select_dtypes(include=['int64','float64'])

# %%
plt.figure(figsize=(16, 8))
sns.heatmap(numeric_df.corr(),annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation of data")
plt.show()
